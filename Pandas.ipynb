# %%
import pandas as pd

# %%
pd.read_csv('Book1-demo file.csv')
# Out:
#      name          email  address  pin code sirname
# 0  dhruvi  abc@gmail.com   sbsjfb      5664   bhatt
# 1   akash  xyz@gmail.com  osfkcxc     94216  pandit

# %%
#added 'r' before normal string(path), because it helps convert normal string to raw string.
pd.read_csv(r"C:\Users\Pandits\Desktop\Python Self learning\Self learned python files\Basic Python\ohana-api-master\data\sample-csv\locations.csv")
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
pd.read_csv(r"C:\Users\Pandits\Desktop\Python Self learning\Self learned python files\Basic Python\ohana-api-master\data\sample-csv\taxonomy.csv")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
# if there is no names of columns
pd.read_csv(r"C:\Users\Pandits\Desktop\Python Self learning\Self learned python files\Basic Python\ohana-api-master\data\sample-csv\taxonomy.csv", header=None)
# Out:
#                0                             1          2  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         3
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
# if I want to give my own column names
df= pd.read_csv(r"C:\Users\Pandits\Desktop\Python Self learning\Self learned python files\Basic Python\ohana-api-master\data\sample-csv\taxonomy.csv", names= ["a","b","c","d"])

# %%
df
# Out:
#                a                             b          c  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         d
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
df.dtypes
# Out:
# a    object
# b    object
# c    object
# d    object
# dtype: object

# %%
df.head()
# Out:
#              a                  b          c               d
# 0  taxonomy_id               name  parent_id     parent_name
# 1          101          Emergency        NaN             NaN
# 2       101-01  Disaster Response        101       Emergency
# 3       101-02     Emergency Cash        101       Emergency
# 4    101-02-01  Help Pay for Food     101-02  Emergency Cash

# %%
df.tail()
# Out:
#              a                             b       c                     d
# 286  111-01-07              Workplace Rights  111-01  Advocacy & Legal Aid
# 287     111-02                     Mediation     111                 Legal
# 288     111-03                        Notary     111                 Legal
# 289     111-04                Representation     111                 Legal
# 290     111-05  Translation & Interpretation     111                 Legal

# %%
df.tail(3)
# Out:
#           a                             b    c      d
# 288  111-03                        Notary  111  Legal
# 289  111-04                Representation  111  Legal
# 290  111-05  Translation & Interpretation  111  Legal

# %%
df1=pd.read_csv(r"C:\Users\Pandits\Desktop\Python Self learning\Self learned python files\Basic Python\ohana-api-master\data\sample-csv\taxonomy.csv")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
#if we want to fetch only one column, then is will become series datatype
a=df1["name"]

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
# if we want to fetch more than one column from the data, then it will become dataframe datatype
df2=df1[['name','parent_name']]

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is F0AD-8445
#
#  Directory of C:\Users\Pandits
#
# 12/19/2022  03:29 PM    <DIR>          .
# 12/19/2022  03:29 PM    <DIR>          ..
# 01/02/2022  11:28 PM    <DIR>          .anaconda
# 01/20/2022  02:52 PM    <DIR>          .conda
# 01/24/2022  01:35 AM                43 .condarc
# 09/07/2019  10:30 PM               572 .flrecent
# 07/21/2019  03:45 PM                 0 .icepak_defaults
# 08/08/2019  11:13 PM               156 .icepak_file_open
# 12/18/2022  05:45 PM    <DIR>          .ipynb_checkpoints
# 09/20/2019  05:26 PM    <DIR>          .ipython
# 09/22/2019  12:43 PM    <DIR>          .jupyter
# 01/24/2022  10:38 PM    <DIR>          .matplotlib
# 06/29/2022  10:10 AM    <DIR>          .ms-ad
# 10/04/2019  03:51 PM               194 .python_history
# 12/01/2020  12:10 AM    <DIR>          .VirtualBox
# 03/23/2021  11:10 PM    <DIR>          3D Objects
# 12/18/2022  10:54 PM               122 Book1-demo file.csv
# ...

# %%
pd.read_excel(r"LUSID Excel - Manage Orders.xlsx")

# %%
df=pd.ExcelFile(r"LUSID Excel - Manage Orders.xlsx")

# %%
#list of sub sheet names in one excelsheet 
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
# above excel sheet has many sub sheets as well. we can read specific sheet by mentioning it.
pd.read_excel(r"LUSID Excel - Manage Orders.xlsx", sheet_name="Allocations")
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
# if we want to read sub sheets one by one
for i in df.sheet_names:
    pd.read_excel(r"LUSID Excel - Manage Orders.xlsx",sheet_name=i)

# %% [markdown]
# # Directly github datapath under read.csv. We don't need to download datasets from github. we need to take "Raw" datafile url under read.csv file.
#
# ![image.png](attachment:image.png)

# %%
pd.read_csv(r"https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
